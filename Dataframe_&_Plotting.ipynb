# %% [markdown]
# <a href="https://colab.research.google.com/github/jpandersen61/SQLLiteNotebooks/blob/main/Dataframe_%26_Plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataframe & Plotting

# %% [markdown]
# Brug denne NoteBook til at eksperimentere med DataFrames & Plotting - der er allerede gjort klar med en DataFrame med data for 50 start up virksomheder.

# %% [markdown]
# ### Setting up Python Environment

# %% [markdown]
# Import Panda library

# %%
import pandas as pd

# %% [markdown]
# ###Indlæsning af en DataFrame

# %%
#Importing the dataset
CSVDataFile="https://raw.githubusercontent.com/jpandersen61/Machine-Learning/refs/heads/main/50_Startups.csv"
StartUpsDataFrame = pd.read_csv(CSVDataFile)
StartUpsDataFrame
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# ### Data præsenteret som kurver

# %%
{
    StartUpsDataFrame[['Profit','R&D Spend','Administration','Marketing Spend']]
    .sort_values(by='Profit',ascending=False)
    .plot(title="Curves for Start-ups",
          xlabel="Company index sorted on profit",
          ylabel="$",
          cmap='Dark2',
          style=["--",".-","-+","-*"]  )
};

# %% [markdown]
# Opgaver - Attribut-liste:
# 1.   Fjern en eller flere attributter (dog ikke 'Profit') fra listen `['Profit','R&D Spend','Administration','Marketing Spend']`, som er en Python liste. Hvad sker der så, når du udfører cellen?

# %% [markdown]
# Opgaver - Sortering:
# 1.   Læs lidt om sortering i DataFrames [Pandas Dataframe.sort_values()](https://www.geeksforgeeks.org/pandas/python-pandas-dataframe-sort_values-set-1/)
# 2.   Prøv at fjerne sorteringsdelen ved at sætte `#` forrest i linien   `#.sort_values(by='Profit',ascending=False)`. Hvilken virkning har det? Hvorfor?
# 1.   Prøv at sortere på eller flere attributter ved at ændre på `by` parameteren. Resulterer det i noget, du forventer?
# 2.   Prøv at ændre `ascending` parameteren til `True`. Giver det mening?

# %% [markdown]
# Opgaver - Line style:
# 1.   Læs lidt om line styles:  [Line plot styles in Matplotlib](https://www.geeksforgeeks.org/python/line-plot-styles-in-matplotlib/)
# 2.   Eksperimentér med at ændre i listen, som er angivet i `style` parameteren: Hvad observerer du?

# %% [markdown]
# Opgaver - Color maps:
# 1.   Læs lidt om color maps  [Choosing Colormaps in Matplotlib](https://matplotlib.org/stable/users/explain/colors/colormaps.html)
# 2.   Find color map 'Dark2', som vi har sat `cmap` parameteren til, i denne beskrivelse.
# 1.   Prøv at specificere andre color maps i `cmap` parameteren: Hvad sker der? Er der noget med rækkefølgen?

# %% [markdown]
# Opgaver - Labels
#
#
# 1.   Læs lidt om plot labels:  [Customizing Plot Labels in Pandas](https://www.geeksforgeeks.org/data-visualization/customizing-plot-labels-in-pandas/)
# 2.   Find de steder i referencen, hvor parametrene `title`, `xlabel` og `ylabel` er omtalt og beskrevet.
# 1.   Prøv at ændre disse parametre. Giver det mening i forhold til det du har læst?

# %% [markdown]
# ###Data præsenteret som søjlediagrammer

# %%
{
    StartUpsDataFrame[['Profit','R&D Spend']]
    .sort_values(by='Profit', ascending=False)
    .plot(title="Profit as bars",
          kind="bar",
          color="#68AB33")
};

# %% [markdown]
# Opgaver:
# 1.   Du skulle nu vide, hvordan du for vist "Profit" og "R&D Spend" med forskellige farver - hvordan?

# %% [markdown]
# ### Histogrammer og frekvensfordelinger

# %%
{
    StartUpsDataFrame[["Profit"]]
    .plot(
        kind="hist")
};

# %% [markdown]
# Opgaver:
# 1.   Er det muligt få vist histogrammet for mere end 1 attribut? Hvordan?
# 2.   Er muligt at styre farvelægningen?

# %%
{
    StartUpsDataFrame['State']
    .value_counts()
    .plot(kind='bar',
          title='Number of Startups by State',
          xlabel='State',
          ylabel='Number of Startups')
};
