# %% [markdown]
# <a href="https://colab.research.google.com/github/jpandersen61/SQLLiteNotebooks/blob/main/Dataframes_Basics_Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DataFrames i Python

# %% [markdown]
# ### Setting up Python Environment

# %% [markdown]
# Import Panda library

# %%
import pandas as pd

# %% [markdown]
# #Programmering med DataFrames

# %% [markdown]
# Brug denne NoteBook til at eksperimentere med DataFrames - der er allerede gjort klar med en DataFrame med data for 50 start up virksomheder.

# %% [markdown]
# ###Indlæsning af en DataFrame

# %%
#Importing the dataset
CSVDataFile="https://raw.githubusercontent.com/jpandersen61/Machine-Learning/refs/heads/main/50_Startups.csv"
StartUpsDataFrame = pd.read_csv(CSVDataFile)
StartUpsDataFrame
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# ###Udtræk information om en DataFrame

# %% [markdown]
# Opgaver:
# 1.   Læs om `DataFrame` metoden [info()](https://www.w3schools.com/python/pandas/ref_df_info.asp). Prøv at udføre `StartUpsDataFrame.info()` i en kode celle herunder. Hvilken information får man herved?
# 2.   Læs om `DataFrame` metoden [describe()](https://www.w3schools.com/python/pandas/ref_df_describe.asp). Prøv at udføre `StartUpsDataFrame.describe()` i en kode celle herunder. Hvilken information får man herved?

# %%
StartUpsDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
StartUpsDataFrame.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
import matplotlib.pyplot as plt
StartUpsDataFrameNoState = StartUpsDataFrame.drop('State', axis=1)
StartUpsDataFrameNoState.hist(bins=10, figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'R&D Spend'}>,
#         <Axes: title={'center': 'Administration'}>],
#        [<Axes: title={'center': 'Marketing Spend'}>,
#         <Axes: title={'center': 'Profit'}>]], dtype=object)

# %% [markdown]
# ###Hent rækker fra en DataFrame

# %% [markdown]
# Læs om følgende metoder på en `DataFrame`:
# 1.   [head(n)](https://www.w3schools.com/python/pandas/ref_df_head.asp) metoden: Se eksempel på anvendelse herunder.
# 2.   [tail(n)](https://www.w3schools.com/python/pandas/ref_df_tail.asp) metoden: Se eksempel på anvendelse herunder.
#
# 1.   [sample(n)](https://www.w3schools.com/python/pandas/ref_df_sample.asp) metoden: Se eksempel på anvendelse herunder.

# %%
StartUpsDataFrame.head(5)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
StartUpsDataFrame.tail(5)
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
StartUpsDataFrame.sample(5)
# Out:
#     R&D Spend  Administration  Marketing Spend     State     Profit
# 5   131876.90        99814.71        362861.36  New York  156991.12
# 43   15505.73       127382.30         35534.17  New York   69758.98
# 41   27892.92        84710.77        164470.71   Florida   77798.83
# 31   61136.38       152701.92         88218.23  New York   97483.56
# 27   72107.60       127864.55        353183.81  New York  105008.31

# %% [markdown]
# Opgaver:
#
# Med inspiration fra ovenstående:
# 1.   Vis mere end 5 rækker fra toppen med Python
# 2.   Vis mere end 5 rækker fra bunden med Python
# 1.   Vis mere end 5 tilfældige rækker med Python

# %% [markdown]
# ###Udskriv DataFrame til Excel

# %% [markdown]
# Opgave:
#
# Prøv at udskrive din `DataFrame` til en Excel fil ved fjerne kommentar tegnet '#' fra nedenstående celler og derefter udføre disse. Du kan herefter finde Excel filen på drive drive

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#ExcelFilePath = "drive/My Drive/Colab Notebooks/FiftyStartUps.xlsx"

# %%
#with pd.ExcelWriter(ExcelFilePath, mode='w') as writer:
#     StartUpsDataFrame.to_excel(writer, sheet_name='Companies')

# %% [markdown]
# ###DataFrames med AI

# %% [markdown]
# Opgaver:
#
# Med Generate code ... prøv at prompte med følgende:
# 1.   'only first five'
# 2.   'do not show state'
# 1.   Find selv på noget
#
# 1.   Prøv at forklare ved der sker med udgangspunkt i referencedokmnetationen til [pandas.DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html)

# %%
CSVDataFile="https://raw.githubusercontent.com/jpandersen61/Machine-Learning/refs/heads/main/50_Startups.csv"
StartUpsDataFrameTestAI = pd.read_csv(CSVDataFile)
StartUpsDataFrameTestAI
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...
