# %% [markdown]
# <a href="https://colab.research.google.com/github/jpandersen61/SQLLiteNotebooks/blob/main/WeatherStackRESTAPI_Continued.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Weatherstack REST API

# %%
import pandas as pd
import requests

# %% [markdown]
# ## Access key

# %% [markdown]
# ### Opgave(r) - Allerede løst:

# %% [markdown]
# 1.   Få din Weatherstack access key på https://weatherstack.com
# 2.   Lav en variabel `AccessKey`, som holder din access key

# %%
#AccessKey="sæt din weather stack access key ind her"
AccessKey="1d5cf0b0e4d8b9adb1b1ff01e1f4dd7f"

# %% [markdown]
# ## Hent byvejr

# %% [markdown]
# Din access key skulle nu give dig adgang til hente informationer vejret fra forskellige lokationer

# %% [markdown]
# ### Opgave(r) - Allerede løst:

# %% [markdown]
# 1. Kør de 2 kodeceller herunder for at får information om vejret i New York
# 2. Hvilke informationer får du om vejret i New York ?
# 3. Lav på tilsvarende vis kodeceller, hvor du henter det aktuelle vejr for et par andre byer - f.eks. London og Paris
# 4. Prøv også med Roskilde - stemmer det med det aktuelle vejr i Roskilde?

# %% [markdown]
# ### Hent aktuel vejr for New York

# %%
#Konstruer endpoint for aktuelt New York vejr
NewYorkWeatherURL=f"http://api.weatherstack.com/current?access_key={AccessKey}&query=New York"
NewYorkWeatherURL
# Out:
# 'http://api.weatherstack.com/current?access_key=1d5cf0b0e4d8b9adb1b1ff01e1f4dd7f&query=New York'

# %%
#Brug WeatherStack REST API til at hente aktuelle vejrdata for New York
response = requests.get(NewYorkWeatherURL)
NewYorkWeatherJSON=response.json()
NewYorkWeatherJSON
# Out:
# {'success': False,
#  'error': {'code': 615,
#   'type': 'request_failed',
#   'info': 'Your API request failed. Please try again or contact support.'}}

# %%
#JSON Object bliver til en dictionary i Python (dict)
type(NewYorkWeatherJSON)
# Out:
# dict

# %% [markdown]
# ### Hent aktuel vejr for London

# %%
#Konstruer endpoint for aktuelt London vejr
LondonWeatherURL=f"http://api.weatherstack.com/current?access_key={AccessKey}&query=London"
LondonWeatherURL
# Out:
# 'http://api.weatherstack.com/current?access_key=1d5cf0b0e4d8b9adb1b1ff01e1f4dd7f&query=London'

# %%
#Brug WeatherStack REST API til at hente aktuelle vejrdata for London
response = requests.get(LondonWeatherURL)
LondonWeatherJSON=response.json()
LondonWeatherJSON
# Out:
# {'success': False,
#  'error': {'code': 615,
#   'type': 'request_failed',
#   'info': 'Your API request failed. Please try again or contact support.'}}

# %%
#JSON Object bliver til en dictionary i Python (dict)
type(LondonWeatherJSON)
# Out:
# dict

# %% [markdown]
# ### Hent aktuel vejr for Paris

# %%
#Konstruer endpoint for aktuelt Paris vejr
ParisWeatherURL=f"http://api.weatherstack.com/current?access_key={AccessKey}&query=Paris"
ParisWeatherURL
# Out:
# 'http://api.weatherstack.com/current?access_key=4a28256c45f513f1567d50f53827ce23&query=Paris'

# %%
#Brug WeatherStack REST API til at hente aktuelle vejrdata for Paris
response = requests.get(ParisWeatherURL)
ParisWeatherJSON=response.json()
ParisWeatherJSON
# Out:
# {'request': {'type': 'City',
#   'query': 'Paris, France',
#   'language': 'en',
#   'unit': 'm'},
#  'location': {'name': 'Paris',
#   'country': 'France',
#   'region': 'Ile-de-France',
#   'lat': '48.867',
#   'lon': '2.333',
#   'timezone_id': 'Europe/Paris',
#   'localtime': '2026-04-06 22:56',
#   'localtime_epoch': 1775516160,
#   'utc_offset': '2.0'},
#  'current': {'observation_time': '08:56 PM',
#   'temperature': 11,
#   'weather_code': 113,
#   'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'],
#   'weather_descriptions': ['Clear '],
#   'astro': {'sunrise': '07:18 AM',
#    'sunset': '08:29 PM',
#    'moonrise': '12:49 AM',
#    'moonset': '08:38 AM',
#    'moon_phase': 'Waning Gibbous',
#    'moon_illumination': 86},
#   'air_quality': {'co': '235.85',
#    'no2': '41.05',
#    'o3': '74',
#    'so2': '3.45',
#    'pm2_5': '8.95',
#    'pm10': '16.65',
#    'us-epa-index': '1',
#    'gb-defra-index': '1'},
# ...

# %%
#JSON Object bliver til en dictionary i Python (dict)
type(ParisWeatherJSON)
# Out:
# dict

# %% [markdown]
# ### Hent aktuel vejr for Roskilde

# %%
#Konstruer endpoint for aktuelt Roskilde vejr
RoskildeWeatherURL=f"http://api.weatherstack.com/current?access_key={AccessKey}&query=Roskilde"
RoskildeWeatherURL
# Out:
# 'http://api.weatherstack.com/current?access_key=4a28256c45f513f1567d50f53827ce23&query=Roskilde'

# %%
#Brug WeatherStack REST API til at hente aktuelle vejrdata for Roskilde
response = requests.get(RoskildeWeatherURL)
RoskildeWeatherJSON=response.json()
RoskildeWeatherJSON
# Out:
# {'request': {'type': 'City',
#   'query': 'Roskilde, Denmark',
#   'language': 'en',
#   'unit': 'm'},
#  'location': {'name': 'Roskilde',
#   'country': 'Denmark',
#   'region': 'Sjelland',
#   'lat': '55.650',
#   'lon': '12.083',
#   'timezone_id': 'Europe/Copenhagen',
#   'localtime': '2026-04-06 22:55',
#   'localtime_epoch': 1775516100,
#   'utc_offset': '2.0'},
#  'current': {'observation_time': '08:55 PM',
#   'temperature': 6,
#   'weather_code': 113,
#   'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'],
#   'weather_descriptions': ['Clear '],
#   'astro': {'sunrise': '06:30 AM',
#    'sunset': '07:59 PM',
#    'moonrise': '12:53 AM',
#    'moonset': '07:12 AM',
#    'moon_phase': 'Waning Gibbous',
#    'moon_illumination': 86},
#   'air_quality': {'co': '159.85',
#    'no2': '2.35',
#    'o3': '87',
#    'so2': '1.15',
#    'pm2_5': '4.75',
#    'pm10': '13.05',
#    'us-epa-index': '1',
# ...

# %%
#JSON Object bliver til en dictionary i Python (dict)
type(RoskildeWeatherJSON)
# Out:
# dict

# %% [markdown]
# ## Udtræk af vejrdata

# %% [markdown]
# ### Opgave(r) - Allerede løst:

# %% [markdown]
# 1.   Lav en `DataFrame` med JSON vejrdata for byerne - f.eks. a la det her `CityWeather=pd.DataFrame([NewYorkWeather,LondonWeather,ParisWeather])`
# 2.   Lav en `DataFrame` med lokationer - f.eks. a la det her `locations=CityWeather['location'].apply(pd.Series)`
# 3. Lav en `DataFrame` med aktuelt vejr - f.eks. a la det her `currents=CityWeather['current'].apply(pd.Series)`

# %% [markdown]
# ### Lav en DataFrame med JSON vejrdata

# %%
#Kombiner de 4 dictionaries i en dataframe
CityWeather=pd.DataFrame([NewYorkWeatherJSON,LondonWeatherJSON,ParisWeatherJSON,RoskildeWeatherJSON])
CityWeather
# Out:
#                                              request  \
# 0  {'type': 'City', 'query': 'New York, United St...
# 1  {'type': 'City', 'query': 'London, United King...
# 2  {'type': 'City', 'query': 'Paris, France', 'la...
# 3  {'type': 'City', 'query': 'Roskilde, Denmark',...
#
#                                             location  \
# 0  {'name': 'New York', 'country': 'United States...
# 1  {'name': 'London', 'country': 'United Kingdom'...
# 2  {'name': 'Paris', 'country': 'France', 'region...
# 3  {'name': 'Roskilde', 'country': 'Denmark', 're...
#
#                                              current
# 0  {'observation_time': '08:55 PM', 'temperature'...
# 1  {'observation_time': '08:56 PM', 'temperature'...
# 2  {'observation_time': '08:56 PM', 'temperature'...
# 3  {'observation_time': '08:55 PM', 'temperature'...

# %%
#Check at vi får DataFrame ud af det
type(CityWeather)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Lav en `DataFrame` med lokationer

# %%
locations=CityWeather['location'].apply(pd.Series)
locations
# Out:
#        name                   country                          region     lat  \
# 0  New York  United States of America                        New York  40.714
# 1    London            United Kingdom  City of London, Greater London  51.517
# 2     Paris                    France                   Ile-de-France  48.867
# 3  Roskilde                   Denmark                        Sjelland  55.650
#
#        lon        timezone_id         localtime  localtime_epoch utc_offset
# 0  -74.006   America/New_York  2026-04-06 16:55       1775494500       -4.0
# 1   -0.106      Europe/London  2026-04-06 21:56       1775512560        1.0
# 2    2.333       Europe/Paris  2026-04-06 22:56       1775516160        2.0
# 3   12.083  Europe/Copenhagen  2026-04-06 22:55       1775516100        2.0

# %%
#Check at vi får en dataframe ud af det
type(locations)
# Out:
# pandas.core.frame.DataFrame

# %%
#Vi kan f.eks. the bynavnene ud i en Series
locations['name']
# Out:
# 0    New York
# 1      London
# 2       Paris
# 3    Roskilde
# Name: name, dtype: object

# %%
#Check at vi får Series ud af det
type(locations['name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Lav en `DataFrame` med aktuelt vejr

# %%
currents=CityWeather['current'].apply(pd.Series)
currents
# Out:
#   observation_time  temperature  weather_code  \
# 0         08:55 PM           13           119
# 1         08:56 PM           10           113
# 2         08:56 PM           11           113
# 3         08:55 PM            6           113
#
#                                        weather_icons weather_descriptions  \
# 0  [https://cdn.worldweatheronline.com/images/wsy...            [Cloudy ]
# 1  [https://cdn.worldweatheronline.com/images/wsy...             [Clear ]
# 2  [https://cdn.worldweatheronline.com/images/wsy...             [Clear ]
# 3  [https://cdn.worldweatheronline.com/images/wsy...             [Clear ]
#
#                                                astro  \
# 0  {'sunrise': '06:31 AM', 'sunset': '07:26 PM', ...
# 1  {'sunrise': '06:24 AM', 'sunset': '07:42 PM', ...
# 2  {'sunrise': '07:18 AM', 'sunset': '08:29 PM', ...
# 3  {'sunrise': '06:30 AM', 'sunset': '07:59 PM', ...
#
#                                          air_quality  wind_speed  wind_degree  \
# ...

# %%
#Check at vi en DataFrame ud af det
type(currents)
# Out:
# pandas.core.frame.DataFrame

# %%
locations['name']
# Out:
# 0    New York
# 1      London
# 2       Paris
# 3    Roskilde
# Name: name, dtype: object

# %%
type(locations['name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Grafisk præsentation

# %% [markdown]
# ### Opgave(r) - Allerede løst:

# %% [markdown]
# 1. Generer et søjlediagram (bar chart) over temperaturene i de enkelte byer - brug gerne AI, hvilket kunne være Gemini

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(locations['name'], currents['temperature'], color='skyblue')
plt.xlabel('City')
plt.ylabel('Temperature (°C)')
plt.title('Current Temperature by City')
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# ### Opgave(r):

# %% [markdown]
# 1.   List Prøv ud fra dokumentationen til `matplotlib.pyplot` (https://matplotlib.org/stable/tutorials/pyplot.html) at forklare, hvad hver enkelt kodelinie, der tegner ovenstående kurvediagram, gør.
# 2.   Prøv også at udkommenter en line af gangen med `#` for derved at forstå, hvad der sker.

# %% [markdown]
# ## Grafisk præsentatation forsat og mere REST API

# %% [markdown]
# ### Opgave(r):

# %% [markdown]
# 1.   Lav udtræk af data vedr. det aktuelle vejr for nogle flere byer efter eget valg, som vi gjorde de for New York, London, Paris og Roskilde.
# 2.   Integrer vejrdata for de valgte byer i en `DataFrame`
# 3. Generer et søjlediagram med temperaturer for de valgte byer.
# 4. Vha. AI "lav et kurvediagram over temparatur og lufttryk".
# 5. Er du tilfreds med resultatet?
# 6. Hvis ikke, så prøv med en ændret prompt?
# 7. Forklar over for dig selv, hvad den genererede programkode udfører?
# 8. Forsøg med andre grafiske præsentationer, der kunne være relevante?

# %% [markdown]
# ## Prøv med andre dataudtræk

# %% [markdown]
# ### Opgave(r):

# %% [markdown]
# 1.   Prøv med andre dataudtræk fra WeatherStack, der kunne være relevante.
# 2.   Lav grafiske præsentationer af disse data.
